# %% [markdown]
# <a href="https://colab.research.google.com/github/yesahek/Machine_Learning/blob/main/Logistic%20Regression/SigmoidDeadAhead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initializing

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_string = "/content/drive/My Drive/goodtitanic.csv"
data = pd.read_csv(file_string)
data
# Out:
#       pclass  survived     sex      age  sibsp  parch embarked
# 0        1.0       1.0  female  29.0000    0.0    0.0        S
# 1        1.0       1.0    male   0.9167    1.0    2.0        S
# 2        1.0       0.0  female   2.0000    1.0    2.0        S
# 3        1.0       0.0    male  30.0000    1.0    2.0        S
# 4        1.0       0.0  female  25.0000    1.0    2.0        S
# ...      ...       ...     ...      ...    ...    ...      ...
# 1304     3.0       0.0  female  14.5000    1.0    0.0        C
# 1305     3.0       0.0  female      NaN    1.0    0.0        C
# 1306     3.0       0.0    male  26.5000    0.0    0.0        C
# 1307     3.0       0.0    male  27.0000    0.0    0.0        C
# 1308     3.0       0.0    male  29.0000    0.0    0.0        S
#
# [1309 rows x 7 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# ###Key to columns:
#
# `pclass`: passenger class (1-3)
#
# `sibsp`: number of siblings or spouses aboard
#
# `parch`: number of parents or children aboard
#
# `fare`: passenger fare
#
# `embarked`:  port of embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
data.describe(include='all')
# Out:
#              pclass     survived   sex          age        sibsp        parch  \
# count   1309.000000  1309.000000  1309  1046.000000  1309.000000  1309.000000
# unique          NaN          NaN     2          NaN          NaN          NaN
# top             NaN          NaN  male          NaN          NaN          NaN
# freq            NaN          NaN   843          NaN          NaN          NaN
# mean       2.294882     0.381971   NaN    29.881135     0.498854     0.385027
# std        0.837836     0.486055   NaN    14.413500     1.041658     0.865560
# min        1.000000     0.000000   NaN     0.166700     0.000000     0.000000
# 25%        2.000000     0.000000   NaN    21.000000     0.000000     0.000000
# 50%        3.000000     0.000000   NaN    28.000000     0.000000     0.000000
# 75%        3.000000     1.000000   NaN    39.000000     1.000000     0.000000
# max        3.000000     1.000000   NaN    80.000000     8.000000     9.000000
#
#        embarked
# count      1307
# unique        3
# top           S
# freq        914
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   float64
#  1   survived  1309 non-null   float64
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   float64
#  5   parch     1309 non-null   float64
#  6   embarked  1307 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 71.7+ KB

# %% [markdown]
# ## Preprocessing

# %%
data.isnull().sum()

# %%
#Remove samples (rows) if NaN values are present.
data = data.dropna(axis=0) # axis=0 specifies we're operating on rows
print(f"The dataset's shape without NaN values: {data.shape}")
# Out:
# The dataset's shape without NaN values: (1044, 7)

# %%
data = pd.get_dummies(data)
data = data.drop(columns=['sex_male']) # all information is already included in sex_female, so there's no need to keep this feature
data.head()
# Out:
#    pclass  survived      age  sibsp  parch  sex_female  embarked_C  \
# 0     1.0       1.0  29.0000    0.0    0.0        True       False
# 1     1.0       1.0   0.9167    1.0    2.0       False       False
# 2     1.0       0.0   2.0000    1.0    2.0        True       False
# 3     1.0       0.0  30.0000    1.0    2.0       False       False
# 4     1.0       0.0  25.0000    1.0    2.0        True       False
#
#    embarked_Q  embarked_S
# 0       False        True
# 1       False        True
# 2       False        True
# 3       False        True
# 4       False        True

# %%
# first split x and y
X = data.drop("survived", axis=1)
y = data.loc[:, "survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)
print(f"X train length: {len(X_train)}, Y train length: {len(y_train)}")
print(f"X test length: {len(X_test)}, Y test length {len(y_test)}")
# Out:
# X train length: 730, Y train length: 730
# X test length: 314, Y test length 314

# %% [markdown]
# ## Training

# %%
from sklearn.linear_model import LogisticRegression
log_reg_model = LogisticRegression(max_iter=500)
log_reg_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# ## Testing

# %%
log_reg_model.score(X_test, y_test)
# Out:
# 0.7834394904458599

# %% [markdown]
# ## Deployment

# %%
leo = pd.DataFrame({"pclass": [3.0], "age": [23.0000], "sibsp": [0.0],
                    "parch": [0.0], "sex_female": [0.0],
                    "embarked_C":[1], "embarked_Q": [0], "embarked_S": [0]})
kate = pd.DataFrame({"pclass": [1.0], "age": [22.0000], "sibsp": [1.0],
                     "parch": [1.0], "sex_female": [1.0],
                     "embarked_C":[0], "embarked_Q": [1], "embarked_S": [0]})

leos_fate = log_reg_model.predict(leo)
kates_fate = log_reg_model.predict(kate)

# %%
print(leos_fate)
# Out:
# [0.]

# %%
print(kates_fate)
# Out:
# [1.]
